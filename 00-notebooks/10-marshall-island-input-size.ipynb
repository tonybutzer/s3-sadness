# %%
! aws s3 ls dev-et-data/in/Marshall_Islands/ --human --sum --recur
# Out:
# 2021-06-10 17:14:06   65.5 KiB in/Marshall_Islands/ETo/pet_001.tif
# 2021-06-10 17:14:08   65.5 KiB in/Marshall_Islands/ETo/pet_002.tif
# 2021-06-10 17:14:08   65.5 KiB in/Marshall_Islands/ETo/pet_003.tif
# 2021-06-10 17:14:08   65.5 KiB in/Marshall_Islands/ETo/pet_004.tif
# 2021-06-10 17:14:07   65.5 KiB in/Marshall_Islands/ETo/pet_005.tif
# 2021-06-10 17:14:08   65.5 KiB in/Marshall_Islands/ETo/pet_006.tif
# 2021-06-10 17:14:09   65.5 KiB in/Marshall_Islands/ETo/pet_007.tif
# 2021-06-10 17:14:09   65.5 KiB in/Marshall_Islands/ETo/pet_008.tif
# 2021-06-10 17:14:09   65.5 KiB in/Marshall_Islands/ETo/pet_009.tif
# 2021-06-10 17:14:10   65.5 KiB in/Marshall_Islands/ETo/pet_010.tif
# 2021-06-10 17:14:11   65.5 KiB in/Marshall_Islands/ETo/pet_011.tif
# 2021-06-10 17:14:11   65.5 KiB in/Marshall_Islands/ETo/pet_012.tif
# 2021-06-10 17:14:11   65.5 KiB in/Marshall_Islands/ETo/pet_013.tif
# 2021-06-10 17:14:12   65.5 KiB in/Marshall_Islands/ETo/pet_014.tif
# ...

# %%
! aws s3 ls dev-et-data/in/
# Out:
#                            PRE DelawareRiverBasin/
#                            PRE Global/
#                            PRE Marshall_Islands/
#                            PRE NorthAmerica/
# 2020-08-24 21:23:37        475 configurationfile_referenceET_test.ini

# %%
20* 365 / 60
# Out:
# 121.66666666666667
